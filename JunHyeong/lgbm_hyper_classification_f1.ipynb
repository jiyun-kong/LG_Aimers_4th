# %%
import numpy as np
import random
import os
def seed_everything(seed: int = 24):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
seed_everything(24)

import pandas as pd
import sklearn
from lightgbm import LGBMClassifier
import lightgbm as lgb
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.model_selection import train_test_split as tts
from bayes_opt import BayesianOptimization
from sklearn.model_selection import KFold
from sklearn.metrics import log_loss

# %% [markdown]
# ### train 준비.  이 코드는 LGBM-이진분류-f1 용이다.

# %% [markdown]
# # 기본 성능 파악

# %%
train=pd.read_csv("train_binary_연습.csv")

# %%
X = train.drop(['TARGET'], axis=1)        #대회진행중이면 val 따로 뺴놓고 갖고오자
y = train['TARGET']

train_x, valid_x, train_y, valid_y = tts(X, y, test_size=0.3, random_state=0, shuffle=True, stratify=y)

# %%
# lgbm_clf = LGBMClassifier(n_estimators=500, objective='multiclass')               # macro f1 

# # 모델 학습
# eval_set = [(train_x, train_y), (valid_x, valid_y)]
# lgbm_clf.fit(train_x, train_y, early_stopping_rounds=50, eval_metric="multi_logloss", eval_set=eval_set)

# # F1 Score 계산
# f1 = f1_score(valid_y, lgbm_clf.predict(valid_x), average='macro')
# print('Macro F1 Score: {0:.4f}'.format(f1))

# %%
lgbm_clf = LGBMClassifier(n_estimators=500, objective='binary')                   # f1

# 모델 학습
eval_set = [(train_x, train_y), (valid_x, valid_y)]
early_stopping_callback = lgb.early_stopping(stopping_rounds=50)
lgbm_clf.fit(train_x, train_y,  callbacks=[early_stopping_callback], eval_metric="binary_logloss", eval_set=eval_set)

# F1 Score 계산
pred = lgbm_clf.predict(valid_x)
f1 = f1_score(valid_y, pred, average='binary')  
print('F1 Score: {0:.4f}'.format(f1))
# Out:
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.642252	valid_1's binary_logloss: 0.679709
# F1 Score: 0.7234

# %%
# lgbm_clf = LGBMClassifier(n_estimators=500, objective='binary')                   #roc auc

# # 모델 학습
# eval_set = [(train_x, train_y), (valid_x, valid_y)]
# lgbm_clf.fit(train_x, train_y, early_stopping_rounds=50, eval_metric="auc", eval_set=eval_set)

# # AUC 계산
# pred_prob = lgbm_clf.predict_proba(valid_x)[:, 1]  
# auc = roc_auc_score(valid_y, pred_prob)
# print('AUC Score: {0:.4f}'.format(auc))
# Out:
# [1]	training's auc: 0.683333	training's binary_logloss: 0.670304	valid_1's auc: 0.563348	valid_1's binary_logloss: 0.68034
# [2]	training's auc: 0.825417	training's binary_logloss: 0.652452	valid_1's auc: 0.515837	valid_1's binary_logloss: 0.682139
# [3]	training's auc: 0.800417	training's binary_logloss: 0.642252	valid_1's auc: 0.556561	valid_1's binary_logloss: 0.679709
# [4]	training's auc: 0.825417	training's binary_logloss: 0.627829	valid_1's auc: 0.515837	valid_1's binary_logloss: 0.682631
# [5]	training's auc: 0.800417	training's binary_logloss: 0.619506	valid_1's auc: 0.556561	valid_1's binary_logloss: 0.681332
# [6]	training's auc: 0.825417	training's binary_logloss: 0.607728	valid_1's auc: 0.515837	valid_1's binary_logloss: 0.685053
# [7]	training's auc: 0.825417	training's binary_logloss: 0.600884	valid_1's auc: 0.515837	valid_1's binary_logloss: 0.684602
# [8]	training's auc: 0.825417	training's binary_logloss: 0.591186	valid_1's auc: 0.515837	valid_1's binary_logloss: 0.688882
# [9]	training's auc: 0.844583	training's binary_logloss: 0.580181	valid_1's auc: 0.50905	valid_1's binary_logloss: 0.694836
# [10]	training's auc: 0.845417	training's binary_logloss: 0.572126	valid_1's auc: 0.49095	valid_1's binary_logloss: 0.699545
# [11]	training's auc: 0.847083	training's binary_logloss: 0.562922	valid_1's auc: 0.5	valid_1's binary_logloss: 0.705861
# [12]	training's auc: 0.847083	training's binary_logloss: 0.556015	valid_1's auc: 0.502262	valid_1's binary_logloss: 0.708982
# [13]	training's auc: 0.85125	training's binary_logloss: 0.548441	valid_1's auc: 0.502262	valid_1's binary_logloss: 0.715711
# [14]	training's auc: 0.847083	training's binary_logloss: 0.542423	valid_1's auc: 0.502262	valid_1's binary_logloss: 0.720859
# [15]	training's auc: 0.860417	training's binary_logloss: 0.533865	valid_1's auc: 0.502262	valid_1's binary_logloss: 0.728288
# [16]	training's auc: 0.867083	training's binary_logloss: 0.527301	valid_1's auc: 0.511312	valid_1's binary_logloss: 0.73521
# [17]	training's auc: 0.86375	training's binary_logloss: 0.520064	valid_1's auc: 0.493213	valid_1's binary_logloss: 0.74318
# [18]	training's auc: 0.86375	training's binary_logloss: 0.514502	valid_1's auc: 0.488688	valid_1's binary_logloss: 0.75023
# [19]	training's auc: 0.872083	training's binary_logloss: 0.511814	valid_1's auc: 0.493213	valid_1's binary_logloss: 0.751365
# [20]	training's auc: 0.864583	training's binary_logloss: 0.505507	valid_1's auc: 0.484163	valid_1's binary_logloss: 0.759797
# [21]	training's auc: 0.86625	training's binary_logloss: 0.501156	valid_1's auc: 0.479638	valid_1's binary_logloss: 0.766963
# [22]	training's auc: 0.86875	training's binary_logloss: 0.496643	valid_1's auc: 0.504525	valid_1's binary_logloss: 0.760108
# [23]	training's auc: 0.88125	training's binary_logloss: 0.491331	valid_1's auc: 0.49095	valid_1's binary_logloss: 0.768565
# [24]	training's auc: 0.8925	training's binary_logloss: 0.481327	valid_1's auc: 0.477376	valid_1's binary_logloss: 0.779207
# [25]	training's auc: 0.901667	training's binary_logloss: 0.473125	valid_1's auc: 0.445701	valid_1's binary_logloss: 0.789971
# [26]	training's auc: 0.901667	training's binary_logloss: 0.46639	valid_1's auc: 0.436652	valid_1's binary_logloss: 0.800041
# [27]	training's auc: 0.905833	training's binary_logloss: 0.460744	valid_1's auc: 0.436652	valid_1's binary_logloss: 0.810598
# [28]	training's auc: 0.901667	training's binary_logloss: 0.458617	valid_1's auc: 0.441176	valid_1's binary_logloss: 0.811622
# [29]	training's auc: 0.905833	training's binary_logloss: 0.453906	valid_1's auc: 0.432127	valid_1's binary_logloss: 0.821256
# [30]	training's auc: 0.908333	training's binary_logloss: 0.450289	valid_1's auc: 0.436652	valid_1's binary_logloss: 0.825989
# [31]	training's auc: 0.9075	training's binary_logloss: 0.448397	valid_1's auc: 0.441176	valid_1's binary_logloss: 0.827057
# [32]	training's auc: 0.907083	training's binary_logloss: 0.445051	valid_1's auc: 0.438914	valid_1's binary_logloss: 0.830894
# [33]	training's auc: 0.907083	training's binary_logloss: 0.443502	valid_1's auc: 0.443439	valid_1's binary_logloss: 0.832007
# [34]	training's auc: 0.90875	training's binary_logloss: 0.439354	valid_1's auc: 0.438914	valid_1's binary_logloss: 0.841396
# [35]	training's auc: 0.914583	training's binary_logloss: 0.436024	valid_1's auc: 0.443439	valid_1's binary_logloss: 0.835304
# [36]	training's auc: 0.91125	training's binary_logloss: 0.433271	valid_1's auc: 0.443439	valid_1's binary_logloss: 0.839223
# [37]	training's auc: 0.915417	training's binary_logloss: 0.429762	valid_1's auc: 0.443439	valid_1's binary_logloss: 0.844888
# [38]	training's auc: 0.91625	training's binary_logloss: 0.426631	valid_1's auc: 0.434389	valid_1's binary_logloss: 0.843121
# [39]	training's auc: 0.916667	training's binary_logloss: 0.422709	valid_1's auc: 0.425339	valid_1's binary_logloss: 0.844029
# [40]	training's auc: 0.916667	training's binary_logloss: 0.419221	valid_1's auc: 0.434389	valid_1's binary_logloss: 0.850469
# [41]	training's auc: 0.924167	training's binary_logloss: 0.416423	valid_1's auc: 0.425339	valid_1's binary_logloss: 0.849012
# [42]	training's auc: 0.923333	training's binary_logloss: 0.413276	valid_1's auc: 0.447964	valid_1's binary_logloss: 0.850232
# [43]	training's auc: 0.923333	training's binary_logloss: 0.410931	valid_1's auc: 0.452489	valid_1's binary_logloss: 0.849114
# [44]	training's auc: 0.9275	training's binary_logloss: 0.407632	valid_1's auc: 0.452489	valid_1's binary_logloss: 0.859055
# [45]	training's auc: 0.927917	training's binary_logloss: 0.404196	valid_1's auc: 0.438914	valid_1's binary_logloss: 0.866132
# [46]	training's auc: 0.92625	training's binary_logloss: 0.402307	valid_1's auc: 0.429864	valid_1's binary_logloss: 0.869166
# [47]	training's auc: 0.927083	training's binary_logloss: 0.39963	valid_1's auc: 0.438914	valid_1's binary_logloss: 0.86569
# [48]	training's auc: 0.929583	training's binary_logloss: 0.397022	valid_1's auc: 0.447964	valid_1's binary_logloss: 0.867168
# [49]	training's auc: 0.930833	training's binary_logloss: 0.394643	valid_1's auc: 0.457014	valid_1's binary_logloss: 0.861167
# [50]	training's auc: 0.935	training's binary_logloss: 0.391865	valid_1's auc: 0.452489	valid_1's binary_logloss: 0.869907
# [51]	training's auc: 0.935833	training's binary_logloss: 0.389918	valid_1's auc: 0.452489	valid_1's binary_logloss: 0.874543
# AUC Score: 0.5633

# %% [markdown]
# # 옵션 1 (cv 없이) 사이킷런 래퍼 사용

# %%
# parameter 별로 search할 범위를 설정. 
bayesian_params = {
    'learning_rate': (0.01, 0.2),
    'max_depth': (6, 16),                 #이상
    'num_leaves': (24, 64), 
    'min_child_samples': (10, 200), 
    'min_child_weight':(1, 50),    
    'subsample':(0.5, 1.0),               #이상 
    'colsample_bytree': (0.5, 1.0),       #고정
    'max_bin':(10, 500),                  #이상 
    'reg_lambda':(0.001, 10),             
    'reg_alpha': (0.01, 50) 
}

# %%
def lgb_roc_eval(learning_rate, max_depth, num_leaves, min_child_samples, min_child_weight, subsample, 
                colsample_bytree,max_bin, reg_lambda, reg_alpha):
    params = {
        "n_estimators":500, 
        "learning_rate": max(round(learning_rate),0.01),
        'max_depth': int(round(max_depth)),  #  호출 시 실수형 값이 들어오므로 정수형 하이퍼 파라미터는 정수형으로 변경 
        'num_leaves': int(round(num_leaves)), 
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0), 
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),            #10이상이 일반적
        'reg_lambda': max(reg_lambda,0),                    #0이상이 일반적
        'reg_alpha': max(reg_alpha, 0)
    }
    print(params)
    early_stopping_callback = lgb.early_stopping(stopping_rounds=100)
    log_callback = lgb.log_evaluation(period=100)   #중간과정 출력
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= "binary_logloss",  
                callbacks=[early_stopping_callback,log_callback])
    pred = lgb_model.predict(valid_x)
    f1 = f1_score(valid_y, pred, average='binary')
    
    return f1

# %%
lgbBO = BayesianOptimization(lgb_roc_eval, bayesian_params , random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)                         #init_points(초기 지정 파라미터개수) (5~20), n_iter(한 셋 반복수) (10~100)
# Out:
# |   iter    |  target   | colsam... | learni... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 11, 'num_leaves': 42, 'min_child_samples': 90, 'min_child_weight': 33, 'subsample': 0.6917207594128889, 'colsample_bytree': 0.7744067519636624, 'max_bin': 305, 'reg_lambda': 9.636663942249792, 'reg_alpha': 44.58973230909617}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 1         | 0.7234    | 0.7744    | 0.1459    | 305.4     | 11.45     | 90.49     | 32.65     | 41.5      | 44.59     | 9.637     | 0.6917    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 15, 'num_leaves': 25, 'min_child_samples': 23, 'min_child_weight': 5, 'subsample': 0.9350060741234096, 'colsample_bytree': 0.8958625190413323, 'max_bin': 288, 'reg_lambda': 7.7817893527475555, 'reg_alpha': 41.63266607894142}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 2         | 0.7234    | 0.8959    | 0.1105    | 288.3     | 15.26     | 23.5      | 5.269     | 24.81     | 41.63     | 7.782     | 0.935     |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 14, 'num_leaves': 30, 'min_child_samples': 32, 'min_child_weight': 32, 'subsample': 0.7073309699952618, 'colsample_bytree': 0.989309171116382, 'max_bin': 236, 'reg_lambda': 5.218961369178968, 'reg_alpha': 47.233999163308695}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 3         | 0.7234    | 0.9893    | 0.1618    | 236.1     | 13.81     | 32.47     | 32.36     | 29.73     | 47.23     | 5.219     | 0.7073    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 12, 'num_leaves': 48, 'min_child_samples': 14, 'min_child_weight': 31, 'subsample': 0.8409101495517417, 'colsample_bytree': 0.6322778060523135, 'max_bin': 234, 'reg_lambda': 9.437537037067727, 'reg_alpha': 30.8505305037691}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 4         | 0.7234    | 0.6323    | 0.1571    | 233.5     | 11.68     | 13.57     | 31.26     | 48.48     | 30.85     | 9.438     | 0.8409    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 32, 'min_child_samples': 137, 'min_child_weight': 34, 'subsample': 0.6818553854713113, 'colsample_bytree': 0.679753950286893, 'max_bin': 352, 'reg_lambda': 3.1549680808909146, 'reg_alpha': 6.455025619766117}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 5         | 0.7234    | 0.6798    | 0.09304   | 351.8     | 6.602     | 136.7     | 33.86     | 32.42     | 6.455     | 3.155     | 0.6819    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 6, 'num_leaves': 48, 'min_child_samples': 200, 'min_child_weight': 10, 'subsample': 0.6210417164903171, 'colsample_bytree': 0.6323243326095025, 'max_bin': 10, 'reg_lambda': 5.984708701800913, 'reg_alpha': 12.167716615594301}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 6         | 0.7234    | 0.6323    | 0.1675    | 10.04     | 6.018     | 199.8     | 10.35     | 48.09     | 12.17     | 5.985     | 0.621     |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 12, 'num_leaves': 60, 'min_child_samples': 193, 'min_child_weight': 13, 'subsample': 0.5594869865540928, 'colsample_bytree': 0.6084253627115292, 'max_bin': 498, 'reg_lambda': 1.6964580044117683, 'reg_alpha': 42.52268728505121}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 7         | 0.7234    | 0.6084    | 0.1971    | 498.5     | 12.17     | 192.5     | 13.09     | 59.74     | 42.52     | 1.696     | 0.5595    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 8, 'num_leaves': 56, 'min_child_samples': 168, 'min_child_weight': 4, 'subsample': 0.7428232190243529, 'colsample_bytree': 0.5497576424599168, 'max_bin': 55, 'reg_lambda': 9.311340464565694, 'reg_alpha': 0.8112898310600849}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 8         | 0.7234    | 0.5498    | 0.1905    | 55.19     | 7.865     | 168.2     | 3.64      | 56.29     | 0.8113    | 9.311     | 0.7428    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 11, 'num_leaves': 62, 'min_child_samples': 21, 'min_child_weight': 4, 'subsample': 0.6738987347857636, 'colsample_bytree': 0.8932066496768657, 'max_bin': 460, 'reg_lambda': 9.468822567281057, 'reg_alpha': 0.8645089292985971}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.641181	valid_1's binary_logloss: 0.679858
# Early stopping, best iteration is:
# [89]	training's binary_logloss: 0.644982	valid_1's binary_logloss: 0.679685
# | 9         | 0.7234    | 0.8932    | 0.03755   | 460.4     | 11.22     | 21.28     | 3.746     | 62.15     | 0.8645    | 9.469     | 0.6739    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 13, 'num_leaves': 31, 'min_child_samples': 196, 'min_child_weight': 45, 'subsample': 0.9446572520484, 'colsample_bytree': 0.5841069124624165, 'max_bin': 487, 'reg_lambda': 2.619663271517766, 'reg_alpha': 2.6020272687263675}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 10        | 0.7234    | 0.5841    | 0.06175   | 487.2     | 13.01     | 196.1     | 45.09     | 31.2      | 2.602     | 2.62      | 0.9447    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 11, 'num_leaves': 25, 'min_child_samples': 176, 'min_child_weight': 10, 'subsample': 0.7279426275667719, 'colsample_bytree': 0.7620091700297207, 'max_bin': 389, 'reg_lambda': 4.813729124644775, 'reg_alpha': 23.240427593313516}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 11        | 0.7234    | 0.762     | 0.0554    | 388.8     | 11.08     | 175.9     | 9.892     | 25.27     | 23.24     | 4.814     | 0.7279    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 11, 'num_leaves': 29, 'min_child_samples': 100, 'min_child_weight': 15, 'subsample': 0.6254679701224573, 'colsample_bytree': 0.7121971699683092, 'max_bin': 482, 'reg_lambda': 8.257695402751272, 'reg_alpha': 3.837942720163452}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 12        | 0.7234    | 0.7122    | 0.0626    | 481.9     | 10.52     | 100.1     | 14.6      | 28.73     | 3.838     | 8.258     | 0.6255    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 13, 'num_leaves': 31, 'min_child_samples': 111, 'min_child_weight': 50, 'subsample': 0.8459604747360912, 'colsample_bytree': 0.7599177374008936, 'max_bin': 167, 'reg_lambda': 9.238719969979112, 'reg_alpha': 44.83037424250424}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 13        | 0.7234    | 0.7599    | 0.1102    | 167.1     | 12.9      | 110.8     | 49.95     | 31.16     | 44.83     | 9.239     | 0.846     |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 13, 'num_leaves': 58, 'min_child_samples': 199, 'min_child_weight': 45, 'subsample': 0.789944879271941, 'colsample_bytree': 0.6585530305349787, 'max_bin': 140, 'reg_lambda': 9.914396659717807, 'reg_alpha': 32.15979807663927}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 14        | 0.7234    | 0.6586    | 0.06901   | 139.9     | 13.13     | 198.9     | 44.8      | 58.43     | 32.16     | 9.914     | 0.7899    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 8, 'num_leaves': 38, 'min_child_samples': 170, 'min_child_weight': 36, 'subsample': 0.7926692943887581, 'colsample_bytree': 0.6271133913879874, 'max_bin': 165, 'reg_lambda': 8.981927467672042, 'reg_alpha': 16.075592785100305}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 15        | 0.7234    | 0.6271    | 0.1362    | 165.2     | 7.586     | 170.3     | 35.85     | 38.21     | 16.08     | 8.982     | 0.7927    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 14, 'num_leaves': 25, 'min_child_samples': 105, 'min_child_weight': 50, 'subsample': 0.8477310102457282, 'colsample_bytree': 0.5897775723310514, 'max_bin': 477, 'reg_lambda': 1.1921016485273737, 'reg_alpha': 10.095920089233628}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 16        | 0.7234    | 0.5898    | 0.02225   | 477.0     | 13.91     | 104.7     | 49.57     | 25.18     | 10.1      | 1.192     | 0.8477    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 6, 'num_leaves': 63, 'min_child_samples': 11, 'min_child_weight': 48, 'subsample': 0.8727905366471629, 'colsample_bytree': 0.6006207747730927, 'max_bin': 18, 'reg_lambda': 6.047351278736796, 'reg_alpha': 28.10506914586344}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 17        | 0.7234    | 0.6006    | 0.1134    | 18.21     | 6.019     | 11.11     | 47.77     | 63.1      | 28.11     | 6.047     | 0.8728    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 30, 'min_child_samples': 19, 'min_child_weight': 12, 'subsample': 0.8641282561072103, 'colsample_bytree': 0.8715026451528486, 'max_bin': 13, 'reg_lambda': 6.475082615553411, 'reg_alpha': 1.289513183660726}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 18        | 0.7234    | 0.8715    | 0.1478    | 13.43     | 9.961     | 18.98     | 11.6      | 30.07     | 1.29      | 6.475     | 0.8641    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 8, 'num_leaves': 31, 'min_child_samples': 191, 'min_child_weight': 6, 'subsample': 0.8627783012543008, 'colsample_bytree': 0.5039049771472874, 'max_bin': 26, 'reg_lambda': 7.637973090736702, 'reg_alpha': 44.664518931956366}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 19        | 0.7234    | 0.5039    | 0.1185    | 26.44     | 7.901     | 191.1     | 6.167     | 30.53     | 44.66     | 7.638     | 0.8628    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 11, 'num_leaves': 54, 'min_child_samples': 115, 'min_child_weight': 45, 'subsample': 0.797918829899513, 'colsample_bytree': 0.9492499522265287, 'max_bin': 496, 'reg_lambda': 2.9624764889857995, 'reg_alpha': 3.414347291643709}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 20        | 0.7234    | 0.9492    | 0.09813   | 495.9     | 10.69     | 114.7     | 44.67     | 54.28     | 3.414     | 2.962     | 0.7979    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 13, 'num_leaves': 48, 'min_child_samples': 116, 'min_child_weight': 44, 'subsample': 0.8802591928033174, 'colsample_bytree': 0.9234686312730862, 'max_bin': 264, 'reg_lambda': 5.4784984940554775, 'reg_alpha': 28.353207696963416}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 21        | 0.7234    | 0.9235    | 0.1325    | 264.0     | 13.44     | 116.1     | 44.45     | 48.32     | 28.35     | 5.478     | 0.8803    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 9, 'num_leaves': 53, 'min_child_samples': 75, 'min_child_weight': 44, 'subsample': 0.5353525013459483, 'colsample_bytree': 0.945047842850654, 'max_bin': 435, 'reg_lambda': 8.498512878566029, 'reg_alpha': 25.31910681766515}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 22        | 0.7234    | 0.945     | 0.06284   | 435.1     | 8.921     | 74.76     | 44.31     | 53.38     | 25.32     | 8.499     | 0.5354    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 15, 'num_leaves': 61, 'min_child_samples': 43, 'min_child_weight': 15, 'subsample': 0.6049510367491628, 'colsample_bytree': 0.6989221291923584, 'max_bin': 346, 'reg_lambda': 2.5629141078195103, 'reg_alpha': 26.889201841982647}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 23        | 0.7234    | 0.6989    | 0.065     | 346.4     | 15.26     | 43.34     | 14.91     | 61.0      | 26.89     | 2.563     | 0.605     |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 15, 'num_leaves': 59, 'min_child_samples': 145, 'min_child_weight': 6, 'subsample': 0.5624112998671378, 'colsample_bytree': 0.6603279482603729, 'max_bin': 381, 'reg_lambda': 9.647612735487785, 'reg_alpha': 3.8374407216635555}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 24        | 0.7234    | 0.6603    | 0.08368   | 381.0     | 15.49     | 145.1     | 5.951     | 59.1      | 3.837     | 9.648     | 0.5624    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 62, 'min_child_samples': 196, 'min_child_weight': 1, 'subsample': 0.955955296346205, 'colsample_bytree': 0.7166098130077875, 'max_bin': 479, 'reg_lambda': 3.614796537212764, 'reg_alpha': 47.88374922372157}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 25        | 0.7234    | 0.7166    | 0.09978   | 478.6     | 7.424     | 195.6     | 1.474     | 61.97     | 47.88     | 3.615     | 0.956     |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 9, 'num_leaves': 63, 'min_child_samples': 11, 'min_child_weight': 1, 'subsample': 0.6805871034254054, 'colsample_bytree': 0.7211669273495851, 'max_bin': 492, 'reg_lambda': 0.11591415522263958, 'reg_alpha': 39.057976875243085}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 26        | 0.7234    | 0.7212    | 0.1516    | 491.7     | 8.752     | 10.76     | 1.071     | 63.23     | 39.06     | 0.1159    | 0.6806    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 6, 'num_leaves': 48, 'min_child_samples': 63, 'min_child_weight': 36, 'subsample': 0.9866565324330236, 'colsample_bytree': 0.8555471225275951, 'max_bin': 79, 'reg_lambda': 2.4423896039021167, 'reg_alpha': 16.85799304177139}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 27        | 0.7234    | 0.8555    | 0.1002    | 79.34     | 6.009     | 63.3      | 36.47     | 47.6      | 16.86     | 2.442     | 0.9867    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 16, 'num_leaves': 24, 'min_child_samples': 198, 'min_child_weight': 7, 'subsample': 0.8657902441739362, 'colsample_bytree': 0.6150905224122819, 'max_bin': 48, 'reg_lambda': 2.850864916227455, 'reg_alpha': 48.56302281102067}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 28        | 0.7234    | 0.6151    | 0.1131    | 48.32     | 15.56     | 198.1     | 7.435     | 24.17     | 48.56     | 2.851     | 0.8658    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 12, 'num_leaves': 47, 'min_child_samples': 71, 'min_child_weight': 39, 'subsample': 0.7494135163539236, 'colsample_bytree': 0.8134192402317713, 'max_bin': 39, 'reg_lambda': 1.2025828317695846, 'reg_alpha': 49.476591094380574}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 29        | 0.7234    | 0.8134    | 0.07254   | 38.83     | 11.73     | 70.88     | 38.55     | 47.01     | 49.48     | 1.203     | 0.7494    |
# {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 14, 'num_leaves': 31, 'min_child_samples': 41, 'min_child_weight': 7, 'subsample': 0.820768050972574, 'colsample_bytree': 0.512030721022885, 'max_bin': 227, 'reg_lambda': 3.5159394791651097, 'reg_alpha': 6.9654658652395876}
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# | 30        | 0.7234    | 0.512     | 0.08451   | 226.8     | 13.79     | 41.43     | 7.115     | 31.18     | 6.965     | 3.516     | 0.8208    |
# =================================================================================================================================================

# %%
#lgbBO.res                #수행기록, target은 내가 지정한 평가지표 값

# %%
target_list = []                   #최적의 파라미터를 추출
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)

best = lgbBO.res[np.argmax(np.array(target_list))]  
print(best)
best=best['params']
# Out:
# {'target': 0.7234042553191489, 'params': {'colsample_bytree': 0.7744067519636624, 'learning_rate': 0.14588597961075972, 'max_bin': 305.3540542751055, 'max_depth': 11.448831829968968, 'min_child_samples': 90.4944118743919, 'min_child_weight': 32.64881154026615, 'num_leaves': 41.5034884505077, 'reg_alpha': 44.58973230909617, 'reg_lambda': 9.636663942249792, 'subsample': 0.6917207594128889}}

# %% [markdown]
# ## 최종평가. 최적의 파라미터로 다시 학습

# %%
lgbm_clf = LGBMClassifier(#n_jobs= 6,                  #cpu 코어수 
                          n_estimators=700, 
                          learning_rate=round(best['learning_rate'], 5),
                          max_depth=int(best['max_depth']),
                          num_leaves=int(best['num_leaves']),
                          colsample_bytree = round(best['colsample_bytree'], 5),
                          subsample=round(best['subsample'], 5),
                          max_bin=int(best['max_bin']),
                          reg_alpha=round(best['reg_alpha'], 5),
                          reg_lambda=round(best['reg_lambda'], 5),
                          min_child_weight= int(best['min_child_weight']), 
                          min_child_samples=int(best['min_child_samples']), 
                          verbose=-1,                #학습정보 미출력                          
                          objective='binary')                            

# 모델 학습
early_stopping_callback = lgb.early_stopping(stopping_rounds=50)
eval_set = [(train_x, train_y), (valid_x, valid_y)]                                                                    
lgbm_clf.fit(train_x, train_y, callbacks=[early_stopping_callback], eval_metric="binary_logloss", eval_set=eval_set)

# f1 계산
pred = lgbm_clf.predict(valid_x)
f1 = f1_score(valid_y, pred, average='binary')  
print('F1 Score: {0:.4f}'.format(f1))
# Out:
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# F1 Score: 0.7234

# %% [markdown]
# # 옵션2 (CV 수행),오래걸림, 좀더 일반화된 성능

# %%
X = train.drop(columns=['TARGET'])
y = train['TARGET']

# %%
bayesian_params = {
    'learning_rate': (0.01, 0.2),
    'max_depth': (6, 16),
    'num_leaves': (24, 64),
    'min_data_in_leaf': (10, 200),  # Equivalent to min_child_samples
    'min_child_weight': (1, 50),
    'bagging_fraction': (0.5, 1.0),  # Equivalent to subsample
    'feature_fraction': (0.5, 1.0),  # Equivalent to colsample_bytree
    'max_bin': (10, 500),
    'lambda_l2': (0.001, 10),  # Equivalent to reg_lambda
    'lambda_l1': (0.01, 50)  # Equivalent to reg_alpha
}

# %%
# Wrapper function for cross-validation using KFold
def lgb_kfold_eval(learning_rate, max_depth, num_leaves, min_data_in_leaf, min_child_weight, 
                   bagging_fraction, feature_fraction, max_bin, lambda_l2, lambda_l1):
    params = {
        'learning_rate': round(learning_rate, 2),
        'max_depth': int(max_depth),
        'num_leaves': int(num_leaves),
        'min_child_samples': int(min_data_in_leaf),
        'min_child_weight': int(min_child_weight),
        'subsample': round(bagging_fraction, 2),
        'colsample_bytree': round(feature_fraction, 2),
        'max_bin': int(max_bin),
        'reg_lambda': round(lambda_l2, 2),
        'reg_alpha': round(lambda_l1, 2),
        'objective': 'binary',
        'metric': 'binary_logloss',
        'verbosity': -1,
        'n_estimators': 500,  # Considering fixed number of estimators
        'n_jobs': -1  # Using all CPU cores
    }
    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    log_loss_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_valid = X.iloc[train_index], X.iloc[test_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[test_index]

        lgb_model = LGBMClassifier(**params)
        
        early_stopping_callback = lgb.early_stopping(stopping_rounds=100)            #조기중단
        log_callback = lgb.log_evaluation(period=100)                                #결과 중간 출력       
        lgb_model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],callbacks=[early_stopping_callback,log_callback])
        
        preds = lgb_model.predict_proba(X_valid)[:, 1]
        log_loss_score = log_loss(y_valid, preds)
        log_loss_scores.append(log_loss_score)
    
    return -np.mean(log_loss_scores)  # Negative because BayesianOptimization maximizes the function

# %%
lgbBO = BayesianOptimization(f=lgb_kfold_eval, pbounds=bayesian_params, random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 | learni... |  max_bin  | max_depth | min_ch... | min_da... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] There are no meaningful features, as all feature values are constant.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 66, number of used features: 0
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 67, number of used features: 0
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 67, number of used features: 0
# [LightGBM] [Info] Start training from score 0.575758
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Info] Start training from score 0.567164
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Info] Start training from score 0.567164
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [100]	cv_agg's binary_logloss: 14.7731 + 0.27276
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's binary_logloss: 14.7731 + 0.27276
# | 1         | 14.77     | 0.7744    | 0.8576    | 30.14     | 5.449     | 0.09049   | 326.5     | 10.38     | 44.7      | 193.1     | 39.34     |
# [LightGBM] [Warning] There are no meaningful features, as all feature values are constant.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 66, number of used features: 0
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 67, number of used features: 0
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 67, number of used features: 0
# [LightGBM] [Info] Start training from score 0.575758
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Info] Start training from score 0.567164
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Info] Start training from score 0.567164
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [100]	cv_agg's binary_logloss: 14.7731 + 0.27276
# Did not meet early stopping. Best iteration is:
# [1]	cv_agg's binary_logloss: 14.7731 + 0.27276
# | 30        | 14.77     | 0.5103    | 0.8378    | 17.34     | 8.017     | 0.1465    | 313.0     | 12.12     | 33.08     | 193.9     | 49.91     |
# =================================================================================================================================================

# %%
best = lgbBO.res[np.argmax(np.array(target_list))]
print(best)
best=best['params']
# Out:
# {'target': 14.773116029403882, 'params': {'bagging_fraction': 0.7744067519636624, 'feature_fraction': 0.8575946831862098, 'lambda_l1': 30.142141169821482, 'lambda_l2': 5.449286946785972, 'learning_rate': 0.09049441187439189, 'max_bin': 326.4881154026615, 'max_depth': 10.375872112626926, 'min_child_weight': 44.69687703832191, 'min_data_in_leaf': 193.09592449519556, 'num_leaves': 39.33766075303111}}

# %% [markdown]
# ## 최종평가. 최적의 파라미터로 다시 예측

# %% [markdown]
# #### 옵션2 전용 (파라미터 단어가 조금 다르기때문에 구분해서 실행해야함)

# %%
lgbm_clf = LGBMClassifier(#n_jobs= 6,                  #cpu 코어수 
                          n_estimators=700, 
                          learning_rate=round(best['learning_rate'], 5),
                          max_depth=int(best['max_depth']),
                          num_leaves=int(best['num_leaves']),
                          colsample_bytree = round(best['feature_fraction'], 5),
                          subsample=round(best['bagging_fraction'], 5),
                          max_bin=int(best['max_bin']),
                          reg_alpha=round(best['lambda_l1'], 5),
                          reg_lambda=round(best['lambda_l2'], 5),
                          min_child_weight= int(best['min_child_weight']), 
                          min_child_samples=int(best['min_data_in_leaf']), 
                          verbose=-1,                #학습정보 미출력                          
                          objective='binary')                            

# 모델 학습
early_stopping_callback = lgb.early_stopping(stopping_rounds=50)
eval_set = [(train_x, train_y), (valid_x, valid_y)]                                                                    
lgbm_clf.fit(train_x, train_y, callbacks=[early_stopping_callback], eval_metric="binary_logloss", eval_set=eval_set)

# f1 계산
pred = lgbm_clf.predict(valid_x)
f1 = f1_score(valid_y, pred, average='binary')  
print('F1 Score: {0:.4f}'.format(f1))
# Out:
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.692872	valid_1's binary_logloss: 0.695612
# F1 Score: 0.7234
