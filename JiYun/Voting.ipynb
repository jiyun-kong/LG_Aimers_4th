# %%
import pandas as pd
import numpy as np
import random
import os

SEED = 42
def seed_everything(seed: int = SEED):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
seed_everything()

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import catboost
from catboost import CatBoostClassifier, CatBoostRegressor

from sklearn.metrics import f1_score, roc_auc_score

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('preprocessed_csv/train_preprocessed.csv')
test = pd.read_csv('preprocessed_csv/test_preprocessed.csv')

# %%
train[['com_reg_ver_win_rate', 'ver_win_rate_x', 'ver_win_ratio_per_bu']] = train[['com_reg_ver_win_rate', 'ver_win_rate_x', 'ver_win_ratio_per_bu']].replace(np.nan, 0)
test[['com_reg_ver_win_rate', 'ver_win_rate_x', 'ver_win_ratio_per_bu']] = test[['com_reg_ver_win_rate', 'ver_win_rate_x', 'ver_win_ratio_per_bu']].replace(np.nan, 0)

# %%
def encode_categorical_variables(train, test):
    categorical_columns = train.select_dtypes(include=['object']).columns.tolist()
    
    label_encoders = {}
    
    for col in categorical_columns:
        le = LabelEncoder()
        le = le.fit(train[col])
        train[col] = le.transform(train[col])
        
        for label in np.unique(test[col]):
            if label not in le.classes_:
                le.classes_ = np.append(le.classes_, label)
        test[col] = le.transform(test[col])
    
    return train, test

train, test = encode_categorical_variables(train, test)

# %%
def encode_with_other_category(train, test, column_name):
    le = LabelEncoder()
    train[column_name] = train[column_name].astype(str)  # int를 str로 변환
    le.fit(train[column_name])
    
    # 테스트 데이터에 대해 'other' 카테고리 처리
    # train에 없는 라벨을 기준으로 한다.
    test[column_name] = test[column_name].astype(str)  # int를 str로 변환
    test[column_name] = test[column_name].apply(lambda x: x if x in le.classes_ else 'other')
    
    # 'other' 라벨 추가
    le_classes = np.append(le.classes_, 'other')
    le.classes_ = le_classes
    
    # 라벨 인코딩 적용
    train[column_name] = le.transform(train[column_name])
    test[column_name] = le.transform(test[column_name])
    
    return train, test

train, test = encode_with_other_category(train, test, "customer_idx")
train, test = encode_with_other_category(train, test, "lead_owner")

# %%
train_y = train['is_converted']
train_X = train.drop(columns='is_converted', axis=1)

train_X, valid_X, train_y, valid_y = train_test_split(train_X, train_y, train_size=0.8, shuffle=True, stratify=train_y)
test = test.drop(columns='is_converted', axis=1)

# %% [markdown]
# # Voting

# %%
lgbm = LGBMClassifier(
        nthread=4,
        n_estimators=1000,
        learning_rate=0.02,
        max_depth=10,
        num_leaves=60,
        colsample_bytree=0.511,
        subsample=0.785,
        max_bin=208,
        reg_alpha=7.009,
        reg_lambda=6.579,
        min_child_weight=40,
        min_child_samples=91,
        silent=-1,
        verbose=-1,
        random_state=SEED)

cbc = CatBoostClassifier(
        iterations=10670, 
        od_wait=1507, 
        learning_rate=0.16098437506461638, 
        reg_lambda=24.546834859312227, 
        subsample=0.16549759534249936, 
        random_strength=49.80933051421884, 
        depth=6, 
        min_data_in_leaf=14, 
        leaf_estimation_iterations=14, 
        bagging_temperature=0.39841620949747386, 
        colsample_bylevel=0.6140733146459497,
        verbose=100, 
        task_type='CPU',
        random_state=SEED)

xgb = XGBClassifier(
        colsample_bytree=0.8497054793943353, 
        gamma=3.935081236491979, 
        learning_rate=0.07509368737832518, 
        max_depth=int(7.215329530514387),  
        min_child_weight=int(1.7019371790152105),  
        n_estimators=int(240.30115793246688),  
        subsample=0.971358258121751,
        random_state=SEED)

rf = RandomForestClassifier(
        max_depth=int(77.32983850657278),  
        min_samples_leaf=int(2.9945638773827494),
        min_samples_split=int(3.126668709295796),  
        n_estimators=int(224.4759742656425),
        random_state=SEED)

# lr = LogisticRegression(
#         C=0.41994536370093083, 
#         penalty='l2', 
#         l1_ratio=0.7209270556562788,
#         max_iter=1000,
#         solver='saga',
#         random_state=SEED)

bagging = BaggingClassifier(random_state=SEED)

models = [lgbm, cbc, xgb, rf, bagging]

# %%
# weight 찾기
model_list = ['lgbm', 'cbc', 'xgb', 'rf', 'bagging']
i = 0; model_f1 = {}
best_threshold= 0.0035

for model in models:  
    model.fit(train_X, train_y)
    pred = model.predict(valid_X)
    if model_list[i] == 'cbc':
        pred = np.array(pred) == 'True'
    globals()[f'preds_{model_list[i]}'] = pred

    score = f1_score(valid_y, pred)
    model_f1[model_list[i]] = score
    i += 1
# Out:
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# 0:	learn: 0.5451832	total: 11.5ms	remaining: 2m 2s
# 100:	learn: 0.0080865	total: 1.38s	remaining: 2m 24s
# 200:	learn: 0.0056780	total: 2.56s	remaining: 2m 13s
# 300:	learn: 0.0049295	total: 3.83s	remaining: 2m 11s
# 400:	learn: 0.0044190	total: 5s	remaining: 2m 8s
# 500:	learn: 0.0040814	total: 6.19s	remaining: 2m 5s
# 600:	learn: 0.0037746	total: 7.48s	remaining: 2m 5s
# 700:	learn: 0.0035220	total: 8.65s	remaining: 2m 3s
# 800:	learn: 0.0032956	total: 9.79s	remaining: 2m
# 900:	learn: 0.0031871	total: 10.9s	remaining: 1m 58s
# 1000:	learn: 0.0030325	total: 12.1s	remaining: 1m 56s
# 1100:	learn: 0.0029360	total: 13.2s	remaining: 1m 54s
# 1200:	learn: 0.0028020	total: 14.4s	remaining: 1m 53s
# 1300:	learn: 0.0027176	total: 15.4s	remaining: 1m 51s
# 1400:	learn: 0.0026386	total: 16.6s	remaining: 1m 50s
# 1500:	learn: 0.0025711	total: 17.9s	remaining: 1m 49s
# 1600:	learn: 0.0025189	total: 19s	remaining: 1m 47s
# 1700:	learn: 0.0024575	total: 20.2s	remaining: 1m 46s
# 1800:	learn: 0.0023701	total: 21.3s	remaining: 1m 44s
# 1900:	learn: 0.0023274	total: 22.4s	remaining: 1m 43s
# 2000:	learn: 0.0022776	total: 23.6s	remaining: 1m 42s
# 2100:	learn: 0.0022439	total: 24.6s	remaining: 1m 40s
# 2200:	learn: 0.0022148	total: 25.8s	remaining: 1m 39s
# 2300:	learn: 0.0021954	total: 27s	remaining: 1m 38s
# 2400:	learn: 0.0021763	total: 28s	remaining: 1m 36s
# 2500:	learn: 0.0021305	total: 29.2s	remaining: 1m 35s
# 2600:	learn: 0.0021204	total: 30.3s	remaining: 1m 33s
# 2700:	learn: 0.0021117	total: 31.3s	remaining: 1m 32s
# 2800:	learn: 0.0020907	total: 32.5s	remaining: 1m 31s
# 2900:	learn: 0.0020816	total: 33.5s	remaining: 1m 29s
# 3000:	learn: 0.0020718	total: 34.6s	remaining: 1m 28s
# 3100:	learn: 0.0020645	total: 35.6s	remaining: 1m 27s
# 3200:	learn: 0.0020139	total: 36.9s	remaining: 1m 26s
# 3300:	learn: 0.0019936	total: 38.1s	remaining: 1m 25s
# 3400:	learn: 0.0019741	total: 39.2s	remaining: 1m 23s
# 3500:	learn: 0.0019683	total: 40.4s	remaining: 1m 22s
# 3600:	learn: 0.0019521	total: 41.5s	remaining: 1m 21s
# 3700:	learn: 0.0019399	total: 42.6s	remaining: 1m 20s
# 3800:	learn: 0.0019254	total: 43.8s	remaining: 1m 19s
# 3900:	learn: 0.0019135	total: 44.9s	remaining: 1m 17s
# 4000:	learn: 0.0019114	total: 46s	remaining: 1m 16s
# 4100:	learn: 0.0019018	total: 47.1s	remaining: 1m 15s
# 4200:	learn: 0.0018999	total: 48.2s	remaining: 1m 14s
# 4300:	learn: 0.0018873	total: 49.4s	remaining: 1m 13s
# 4400:	learn: 0.0018824	total: 50.5s	remaining: 1m 11s
# 4500:	learn: 0.0018718	total: 51.6s	remaining: 1m 10s
# 4600:	learn: 0.0018585	total: 52.8s	remaining: 1m 9s
# 4700:	learn: 0.0018527	total: 53.9s	remaining: 1m 8s
# 4800:	learn: 0.0018465	total: 55s	remaining: 1m 7s
# 4900:	learn: 0.0018338	total: 56.2s	remaining: 1m 6s
# 5000:	learn: 0.0018282	total: 57.3s	remaining: 1m 4s
# 5100:	learn: 0.0018111	total: 58.4s	remaining: 1m 3s
# 5200:	learn: 0.0018023	total: 59.6s	remaining: 1m 2s
# 5300:	learn: 0.0017996	total: 1m	remaining: 1m 1s
# 5400:	learn: 0.0017942	total: 1m 1s	remaining: 1m
# 5500:	learn: 0.0017835	total: 1m 2s	remaining: 59.1s
# 5600:	learn: 0.0017739	total: 1m 3s	remaining: 57.9s
# 5700:	learn: 0.0017659	total: 1m 5s	remaining: 56.7s
# 5800:	learn: 0.0017526	total: 1m 6s	remaining: 55.6s
# 5900:	learn: 0.0017489	total: 1m 7s	remaining: 54.6s
# 6000:	learn: 0.0017418	total: 1m 9s	remaining: 54.1s
# 6100:	learn: 0.0017321	total: 1m 11s	remaining: 53.8s
# 6200:	learn: 0.0017251	total: 1m 13s	remaining: 53s
# 6300:	learn: 0.0017201	total: 1m 15s	remaining: 52.1s
# 6400:	learn: 0.0017158	total: 1m 16s	remaining: 50.9s
# 6500:	learn: 0.0017004	total: 1m 17s	remaining: 49.7s
# 6600:	learn: 0.0016947	total: 1m 18s	remaining: 48.5s
# 6700:	learn: 0.0016826	total: 1m 19s	remaining: 47.3s
# 6800:	learn: 0.0016760	total: 1m 21s	remaining: 46.1s
# 6900:	learn: 0.0016729	total: 1m 22s	remaining: 44.9s
# 7000:	learn: 0.0016652	total: 1m 23s	remaining: 43.7s
# 7100:	learn: 0.0016607	total: 1m 24s	remaining: 42.5s
# 7200:	learn: 0.0016575	total: 1m 25s	remaining: 41.4s
# 7300:	learn: 0.0016490	total: 1m 27s	remaining: 40.2s
# 7400:	learn: 0.0016469	total: 1m 28s	remaining: 39s
# 7500:	learn: 0.0016420	total: 1m 29s	remaining: 37.7s
# 7600:	learn: 0.0016342	total: 1m 30s	remaining: 36.5s
# 7700:	learn: 0.0016301	total: 1m 31s	remaining: 35.3s
# 7800:	learn: 0.0016250	total: 1m 32s	remaining: 34.1s
# 7900:	learn: 0.0016230	total: 1m 33s	remaining: 32.9s
# 8000:	learn: 0.0016205	total: 1m 34s	remaining: 31.6s
# 8100:	learn: 0.0016158	total: 1m 35s	remaining: 30.4s
# 8200:	learn: 0.0016123	total: 1m 37s	remaining: 29.2s
# 8300:	learn: 0.0016089	total: 1m 38s	remaining: 28s
# 8400:	learn: 0.0016075	total: 1m 39s	remaining: 26.8s
# 8500:	learn: 0.0016037	total: 1m 40s	remaining: 25.6s
# 8600:	learn: 0.0015968	total: 1m 41s	remaining: 24.4s
# 8700:	learn: 0.0015948	total: 1m 42s	remaining: 23.2s
# 8800:	learn: 0.0015864	total: 1m 43s	remaining: 22s
# 8900:	learn: 0.0015814	total: 1m 44s	remaining: 20.8s
# 9000:	learn: 0.0015736	total: 1m 45s	remaining: 19.7s
# 9100:	learn: 0.0015692	total: 1m 47s	remaining: 18.5s
# 9200:	learn: 0.0015594	total: 1m 48s	remaining: 17.3s
# 9300:	learn: 0.0015557	total: 1m 49s	remaining: 16.1s
# 9400:	learn: 0.0015477	total: 1m 50s	remaining: 14.9s
# 9500:	learn: 0.0015327	total: 1m 51s	remaining: 13.7s
# 9600:	learn: 0.0015317	total: 1m 52s	remaining: 12.6s
# 9700:	learn: 0.0015261	total: 1m 53s	remaining: 11.4s
# 9800:	learn: 0.0015251	total: 1m 55s	remaining: 10.2s
# 9900:	learn: 0.0015142	total: 1m 56s	remaining: 9.04s
# 10000:	learn: 0.0015105	total: 1m 57s	remaining: 7.86s
# 10100:	learn: 0.0015066	total: 1m 58s	remaining: 6.68s
# 10200:	learn: 0.0015037	total: 1m 59s	remaining: 5.51s
# 10300:	learn: 0.0014948	total: 2m	remaining: 4.33s
# 10400:	learn: 0.0014890	total: 2m 2s	remaining: 3.16s
# 10500:	learn: 0.0014832	total: 2m 3s	remaining: 1.99s
# 10600:	learn: 0.0014820	total: 2m 4s	remaining: 811ms
# 10669:	learn: 0.0014812	total: 2m 5s	remaining: 0us

# %%
print(globals()['preds_lgbm'])
print(model_f1)   # {'lgbm': 0.9773429454170957, 'cbc': 0.9804727646454265, 'xgb': 0.9820788530465949, 'rf': 0.9798657718120805, 'bagging': 0.9783281733746131}
# Out:
# [False False  True ... False False False]
# {'lgbm': 0.9773429454170957, 'cbc': 0.9804727646454265, 'xgb': 0.9820788530465949, 'rf': 0.9798657718120805, 'bagging': 0.9783281733746131}

# %%
estimators = [('lgbm', lgbm), ('cbc', cbc), ('xgb', xgb), ('rf', rf), ('bagging', bagging)]
best_model = VotingClassifier(estimators, voting='soft', weights=[1, 2, 2, 1, 1]) # hard voting은 predict_proba 안 됨
best_model.fit(train_X, train_y)
# Out:
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# 0:	learn: 0.5451832	total: 12.7ms	remaining: 2m 15s
# 100:	learn: 0.0080865	total: 1.24s	remaining: 2m 9s
# 200:	learn: 0.0056780	total: 2.42s	remaining: 2m 5s
# 300:	learn: 0.0049295	total: 3.59s	remaining: 2m 3s
# 400:	learn: 0.0044190	total: 4.66s	remaining: 1m 59s
# 500:	learn: 0.0040814	total: 5.72s	remaining: 1m 56s
# 600:	learn: 0.0037746	total: 6.85s	remaining: 1m 54s
# 700:	learn: 0.0035220	total: 7.92s	remaining: 1m 52s
# 800:	learn: 0.0032956	total: 9.17s	remaining: 1m 53s
# 900:	learn: 0.0031871	total: 10.2s	remaining: 1m 50s
# 1000:	learn: 0.0030325	total: 11.2s	remaining: 1m 48s
# 1100:	learn: 0.0029360	total: 12.3s	remaining: 1m 47s
# 1200:	learn: 0.0028020	total: 13.3s	remaining: 1m 45s
# 1300:	learn: 0.0027176	total: 14.4s	remaining: 1m 43s
# 1400:	learn: 0.0026386	total: 15.5s	remaining: 1m 42s
# 1500:	learn: 0.0025711	total: 16.5s	remaining: 1m 40s
# 1600:	learn: 0.0025189	total: 17.5s	remaining: 1m 39s
# 1700:	learn: 0.0024575	total: 18.5s	remaining: 1m 37s
# 1800:	learn: 0.0023701	total: 19.6s	remaining: 1m 36s
# 1900:	learn: 0.0023274	total: 20.6s	remaining: 1m 35s
# 2000:	learn: 0.0022776	total: 21.7s	remaining: 1m 33s
# 2100:	learn: 0.0022439	total: 22.7s	remaining: 1m 32s
# 2200:	learn: 0.0022148	total: 23.7s	remaining: 1m 31s
# 2300:	learn: 0.0021954	total: 24.7s	remaining: 1m 29s
# 2400:	learn: 0.0021763	total: 25.6s	remaining: 1m 28s
# 2500:	learn: 0.0021305	total: 26.7s	remaining: 1m 27s
# 2600:	learn: 0.0021204	total: 27.7s	remaining: 1m 25s
# 2700:	learn: 0.0021117	total: 28.7s	remaining: 1m 24s
# 2800:	learn: 0.0020907	total: 29.7s	remaining: 1m 23s
# 2900:	learn: 0.0020816	total: 30.8s	remaining: 1m 22s
# 3000:	learn: 0.0020718	total: 32s	remaining: 1m 21s
# 3100:	learn: 0.0020645	total: 33.1s	remaining: 1m 20s
# 3200:	learn: 0.0020139	total: 34.2s	remaining: 1m 19s
# 3300:	learn: 0.0019936	total: 35.4s	remaining: 1m 19s
# 3400:	learn: 0.0019741	total: 36.5s	remaining: 1m 18s
# 3500:	learn: 0.0019683	total: 37.6s	remaining: 1m 16s
# 3600:	learn: 0.0019521	total: 38.7s	remaining: 1m 15s
# 3700:	learn: 0.0019399	total: 39.8s	remaining: 1m 15s
# 3800:	learn: 0.0019254	total: 40.9s	remaining: 1m 13s
# 3900:	learn: 0.0019135	total: 42s	remaining: 1m 12s
# 4000:	learn: 0.0019114	total: 43.1s	remaining: 1m 11s
# 4100:	learn: 0.0019018	total: 44.1s	remaining: 1m 10s
# 4200:	learn: 0.0018999	total: 45.3s	remaining: 1m 9s
# 4300:	learn: 0.0018873	total: 46.4s	remaining: 1m 8s
# 4400:	learn: 0.0018824	total: 47.4s	remaining: 1m 7s
# 4500:	learn: 0.0018718	total: 48.7s	remaining: 1m 6s
# 4600:	learn: 0.0018585	total: 50s	remaining: 1m 5s
# 4700:	learn: 0.0018527	total: 51.2s	remaining: 1m 4s
# 4800:	learn: 0.0018465	total: 52.3s	remaining: 1m 3s
# 4900:	learn: 0.0018338	total: 53.4s	remaining: 1m 2s
# 5000:	learn: 0.0018282	total: 54.4s	remaining: 1m 1s
# 5100:	learn: 0.0018111	total: 55.6s	remaining: 1m
# 5200:	learn: 0.0018023	total: 56.6s	remaining: 59.6s
# 5300:	learn: 0.0017996	total: 57.7s	remaining: 58.4s
# 5400:	learn: 0.0017942	total: 58.8s	remaining: 57.3s
# 5500:	learn: 0.0017835	total: 59.8s	remaining: 56.2s
# 5600:	learn: 0.0017739	total: 1m	remaining: 55.1s
# 5700:	learn: 0.0017659	total: 1m 1s	remaining: 54s
# 5800:	learn: 0.0017526	total: 1m 3s	remaining: 52.9s
# 5900:	learn: 0.0017489	total: 1m 4s	remaining: 51.8s
# 6000:	learn: 0.0017418	total: 1m 5s	remaining: 50.7s
# 6100:	learn: 0.0017321	total: 1m 6s	remaining: 49.6s
# 6200:	learn: 0.0017251	total: 1m 7s	remaining: 48.5s
# 6300:	learn: 0.0017201	total: 1m 8s	remaining: 47.4s
# 6400:	learn: 0.0017158	total: 1m 9s	remaining: 46.3s
# 6500:	learn: 0.0017004	total: 1m 10s	remaining: 45.2s
# 6600:	learn: 0.0016947	total: 1m 11s	remaining: 44.2s
# 6700:	learn: 0.0016826	total: 1m 12s	remaining: 43.2s
# 6800:	learn: 0.0016760	total: 1m 14s	remaining: 42.2s
# 6900:	learn: 0.0016729	total: 1m 15s	remaining: 41.2s
# 7000:	learn: 0.0016652	total: 1m 16s	remaining: 40.2s
# 7100:	learn: 0.0016607	total: 1m 17s	remaining: 39.1s
# 7200:	learn: 0.0016575	total: 1m 18s	remaining: 38.1s
# 7300:	learn: 0.0016490	total: 1m 20s	remaining: 37s
# 7400:	learn: 0.0016469	total: 1m 21s	remaining: 36s
# 7500:	learn: 0.0016420	total: 1m 22s	remaining: 34.8s
# 7600:	learn: 0.0016342	total: 1m 23s	remaining: 33.7s
# 7700:	learn: 0.0016301	total: 1m 24s	remaining: 32.7s
# 7800:	learn: 0.0016250	total: 1m 25s	remaining: 31.6s
# 7900:	learn: 0.0016230	total: 1m 26s	remaining: 30.5s
# 8000:	learn: 0.0016205	total: 1m 28s	remaining: 29.4s
# 8100:	learn: 0.0016158	total: 1m 29s	remaining: 28.2s
# 8200:	learn: 0.0016123	total: 1m 30s	remaining: 27.1s
# 8300:	learn: 0.0016089	total: 1m 31s	remaining: 26s
# 8400:	learn: 0.0016075	total: 1m 32s	remaining: 25s
# 8500:	learn: 0.0016037	total: 1m 33s	remaining: 23.9s
# 8600:	learn: 0.0015968	total: 1m 34s	remaining: 22.8s
# 8700:	learn: 0.0015948	total: 1m 35s	remaining: 21.7s
# 8800:	learn: 0.0015864	total: 1m 37s	remaining: 20.6s
# 8900:	learn: 0.0015814	total: 1m 38s	remaining: 19.5s
# 9000:	learn: 0.0015736	total: 1m 39s	remaining: 18.4s
# 9100:	learn: 0.0015692	total: 1m 40s	remaining: 17.3s
# 9200:	learn: 0.0015594	total: 1m 41s	remaining: 16.2s
# 9300:	learn: 0.0015557	total: 1m 42s	remaining: 15.1s
# 9400:	learn: 0.0015477	total: 1m 43s	remaining: 14s
# 9500:	learn: 0.0015327	total: 1m 44s	remaining: 12.9s
# 9600:	learn: 0.0015317	total: 1m 45s	remaining: 11.8s
# 9700:	learn: 0.0015261	total: 1m 47s	remaining: 10.8s
# 9800:	learn: 0.0015251	total: 1m 49s	remaining: 9.7s
# 9900:	learn: 0.0015142	total: 1m 50s	remaining: 8.6s
# 10000:	learn: 0.0015105	total: 1m 52s	remaining: 7.5s
# 10100:	learn: 0.0015066	total: 1m 53s	remaining: 6.39s
# 10200:	learn: 0.0015037	total: 1m 55s	remaining: 5.29s
# 10300:	learn: 0.0014948	total: 1m 56s	remaining: 4.17s
# 10400:	learn: 0.0014890	total: 1m 58s	remaining: 3.06s
# 10500:	learn: 0.0014832	total: 1m 59s	remaining: 1.92s
# 10600:	learn: 0.0014820	total: 2m	remaining: 786ms
# 10669:	learn: 0.0014812	total: 2m 1s	remaining: 0us
# VotingClassifier(estimators=[('lgbm',
#                               LGBMClassifier(colsample_bytree=0.511,
#                                              learning_rate=0.02, max_bin=208,
#                                              max_depth=10, min_child_samples=91,
#                                              min_child_weight=40,
#                                              n_estimators=1000, nthread=4,
#                                              num_leaves=60, random_state=42,
#                                              reg_alpha=7.009, reg_lambda=6.579,
#                                              silent=-1, subsample=0.785,
#                                              verbose=-1)),
#                              ('cbc',
#                               <catboost.core.CatBoostClassifier object at 0x0000013C01...
#                                             max_leaves=None, min_child_weight=1,
#                                             missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=240, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=42, ...)),
#                              ('rf',
#                               RandomForestClassifier(max_depth=77,
#                                                      min_samples_leaf=2,
#                                                      min_samples_split=3,
#                                                      n_estimators=224,
#                                                      random_state=42)),
#                              ('bagging', BaggingClassifier(random_state=42))],
#                  voting='soft', weights=[1, 2, 2, 1, 1])

# %%
pred = best_model.predict(valid_X)
score = f1_score(pred, valid_y) 
print(score) # 검증 스코어
# Out:
# 0.9820420728578758

# %%
# 제출용 prediction
best_threshold = 0.00485
pred_probs = best_model.predict_proba(test)[:, 1]
final_preds = pred_probs >= best_threshold
print(sum(final_preds) / len(final_preds)) # True 비율
# Out:
# 0.32821096566116487

# %%
# True, False로 수정
def convert_to_boolean_vector(input_vector):
    return np.array(input_vector == 1, dtype=bool)          
    
result_vector = convert_to_boolean_vector(final_preds)

# %%
submission = pd.read_csv('submission.csv')
submission['is_converted'] = result_vector
submission.to_csv('submission_csv/voting_submission.csv')
